# %%
import os
import json
import pandas as pd
from SPARQLWrapper import SPARQLWrapper, JSON
# Out:
# /home/ins-alex/.local/lib/python3.8/site-packages/rdflib_jsonld/__init__.py:9: DeprecationWarning: The rdflib-jsonld package has been integrated into rdflib as of rdflib==6.0.1.  Please remove rdflib-jsonld from your project's dependencies.
#   warnings.warn(

# %%
filename = "assignments_from_pool_37642729__16-02-2023"

# translations of the search topics from English to Russian
en_ru_dict = {
    "Male actor born after 1950": "Актёры-мужчины родившиеся после 1950 года",
    "ColdWar politician": "Политики времён холодной войны",
    "Company": "Компании",
    "Soccer club": "Футбольные клубы",
    "Beverage": "Напитки",
    "Active political parties(last 20 years)": "Действующие политические партии (последние 20 лет)",
    "Natural disaster": "Природные катастрофы",
    "Magazine": "Журналы",
    "Nominee of the Academy Award for Best Actor": "Номинанты на Оскар за лучшую мужскую роль",
    "Museum": "Музеи",
    "Mountain higher than 4000m": "Горы выше чем 4000м",
    "Active political party": "Действующие политические партии",
    "WWII politician": "Политики времён второй мировой войны",
    "News presenter": "Телеведущие",
    "Film festival": "Кинофестивали",
    "Newspaper": "Газеты",
    "Lake with the area more than 100 square km": "Озёра с площадью более 100 квадратных км."
}

# invert a dict
ru_en_dict = {v: k for k, v in en_ru_dict.items()}

# %%
df_raw = pd.read_csv(f"/home/ins-alex/Downloads/assignments_from_pool_41212285__24-09-2023(3).tsv", sep="\t")

# %% [markdown]
# # Count the correctenss of the control tasks

# %%
# filter out rows where column GOLDEN:least is NaN
df = df_raw[df_raw["GOLDEN:least"].notna()]

# calculate how many times value from GOLDEN:least equals OUTPUT:least
res = (df["GOLDEN:least"] == df["OUTPUT:least"]).value_counts().reset_index()
res.columns = ["is_equal", "count"]
res_dict = res.set_index("is_equal").to_dict()["count"]

print("Quality of the results:" + str(res_dict[True] / (res_dict[True] + res_dict[False])))
# Out:
# Quality of the results:0.7564247921390779

# %%
df_raw = df_raw[~df_raw["GOLDEN:least"].notna()] # remove control tasks from the dataset

# %% [markdown]
# # Prepare data for the external SHR script

# %% [markdown]
# ## Full

# %%
# leave only important columns
df_shr = df_raw[["INPUT:topic", "INPUT:answer_1", "INPUT:answer_2", "INPUT:answer_3", "INPUT:answer_4", "OUTPUT:most", "OUTPUT:least"]]

# %%
df_shr_dict = {
    "Item1": list(),
    "Item2": list(),
    "Item3": list(),
    "Item4": list(),
    "BestItem": list(),
    "WorstItem": list()
}

for i, row in df_shr.iterrows():
    df_shr_dict["Item1"].append(row["INPUT:answer_1"])
    df_shr_dict["Item2"].append(row["INPUT:answer_2"])
    df_shr_dict["Item3"].append(row["INPUT:answer_3"])
    df_shr_dict["Item4"].append(row["INPUT:answer_4"])
    
    best_idx = row["OUTPUT:most"]
    worst_idx = row["OUTPUT:least"]
    
    df_shr_dict["BestItem"].append(row[f"INPUT:answer_{best_idx}"])
    df_shr_dict["WorstItem"].append(row[f"INPUT:answer_{worst_idx}"])

df_shr_full = pd.DataFrame(df_shr_dict)
df_shr_full.to_csv("/home/ins-alex/Downloads/assignments_from_pool_41212285__24-09-2023_shr_full.tsv", sep=",", index=False)

# %% [markdown]
# ## Category Wise

# %%
for topic in df_shr["INPUT:topic"].unique():
    df_shr_topic = df_shr[df_shr["INPUT:topic"] == topic]

    df_shr_dict = {
        "Item1": list(),
        "Item2": list(),
        "Item3": list(),
        "Item4": list(),
        "BestItem": list(),
        "WorstItem": list()
    }

    for i, row in df_shr_topic.iterrows():
        df_shr_dict["Item1"].append(row["INPUT:answer_1"])
        df_shr_dict["Item2"].append(row["INPUT:answer_2"])
        df_shr_dict["Item3"].append(row["INPUT:answer_3"])
        df_shr_dict["Item4"].append(row["INPUT:answer_4"])
        
        best_idx = row["OUTPUT:most"]
        worst_idx = row["OUTPUT:least"]
        
        df_shr_dict["BestItem"].append(row[f"INPUT:answer_{best_idx}"])
        df_shr_dict["WorstItem"].append(row[f"INPUT:answer_{worst_idx}"])

    df_shr_topic = pd.DataFrame(df_shr_dict)
    df_shr_topic.to_csv(f"../../data/final-crowdsourcing-experiments/ru/topics/{topic}.csv", sep=",", index=False)

# %% [markdown]
# # Create files with scores

# %% [markdown]
# ## Count SHRs for topics

# %%
import re
import subprocess

topics_dir = "/home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics"
df_dct = {"topic": [], "Spearman": [], "Pearson": []}
for file in os.listdir(topics_dir):
    file_path = os.path.join(topics_dir, file.replace(" ", "\ "))
    output = subprocess.check_output(f"/home/ins-alex/multilingual-qa-with-ranking/external-scripts/Best-Worst-Scaling-Scripts/SHR-BWS.pl {file_path}", shell=True, universal_newlines=True)
    lst = output.split("\n")
    pattern_1 = r"Spearman correlation: ([\d.]+)"
    pattern_2 = r"Pearson correlation: ([\d.]+)"    

    match_1 = re.search(pattern_1, lst[0]).group(1)
    match_2 = re.search(pattern_2, lst[1]).group(1)

    df_dct["topic"].append(file.replace(".csv", ""))
    df_dct["Spearman"].append(match_1)
    df_dct["Pearson"].append(match_2)
# Out:
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/англичане.csv ...
# Read 300 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/штат США.csv ...
# Read 204 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/специалист в области информатики.csv ...
# Read 180 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/американцы США.csv ...
# Read 332 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/турки.csv ...
# Read 312 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/спортивный симулятор.csv ...
# Read 421 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/рождественский фильм.csv ...
# Read 225 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/животные.csv ...
# Read 180 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/политолог.csv ...
# Read 236 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/криминальный телесериал.csv ...
# Read 431 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/научная фантастика на телевидении.csv ...
# WARNING: Annotations for the Best and Worst items are identical in line 236.
# Read 370 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/литература ужасов.csv ...
# Read 192 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/боевые искусства.csv ...
# Read 168 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/музыкальная компьютерная игра.csv ...
# Read 271 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/бас гитарист.csv ...
# Read 203 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/музей современного искусства.csv ...
# Read 140 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/президент США.csv ...
# Read 276 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/актёр.csv ...
# Read 515 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/приключенческий фильм.csv ...
# Read 179 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/action.csv ...
# Read 193 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/фильм тайна.csv ...
# Read 204 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/рэпер.csv ...
# Read 467 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/философ.csv ...
# Read 396 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/спортсмен.csv ...
# Read 200 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/многопользовательская игра.csv ...
# Read 261 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/шпионский фильм.csv ...
# Read 204 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/гора.csv ...
# Read 432 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/инженер.csv ...
# Read 379 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/математик.csv ...
# Read 207 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/архитектор.csv ...
# Read 200 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/китайцы.csv ...
# Read 189 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/криминальный фильм.csv ...
# Read 209 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/афроамериканцы.csv ...
# Read 360 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/баскетболист.csv ...
# Read 226 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/музыкальный жанр.csv ...
# Read 257 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/скульптура.csv ...
# Read 254 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/индийцы.csv ...
# Read 308 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/фильм ужасов.csv ...
# Read 257 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/100 женщин.csv ...
# Read 367 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/немцы.csv ...
# Read 180 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/фильм сказка.csv ...
# Read 408 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/гитарист.csv ...
# Read 259 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/итальянцы.csv ...
# Read 322 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/боевик.csv ...
# Read 429 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/спортивный фильм.csv ...
# Read 213 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/теннисист.csv ...
# Read 192 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/компьютерная стратегическая игра.csv ...
# Read 226 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/борец за права женщин.csv ...
# Read 201 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/учёный.csv ...
# Read 228 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/джазмен.csv ...
# WARNING: Annotations for the Best and Worst items are identical in line 195.
# Read 345 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/модельер.csv ...
# Read 189 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/исторический фильм.csv ...
# Read 262 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/растения.csv ...
# Read 238 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/пианист.csv ...
# Read 203 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/комедийный телесериал.csv ...
# Read 396 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/пейзажист.csv ...
# Read 164 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/романтический фильм.csv ...
# Read 264 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/детский фильм.csv ...
# Read 359 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/военный фильм.csv ...
# Read 224 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/однопользовательская игра.csv ...
# Read 201 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/художник.csv ...
# Read 406 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/человек, связанный со спортом.csv ...
# Read 187 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/телефильм.csv ...
# Read 564 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/стендап комик.csv ...
# Read 228 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/аниме фильм.csv ...
# Read 372 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/биолог.csv ...
# Read 488 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/драматический сериал.csv ...
# Read 188 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/программист.csv ...
# Read 178 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/экономист.csv ...
# Read 408 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/большой город в США.csv ...
# Read 355 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/барабанщик.csv ...
# Read 204 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/русские.csv ...
# Read 299 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/3D фильм.csv ...
# Read 423 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/мультфильм.csv ...
# Read 464 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/интернет мем.csv ...
# Read 192 annotations.

# %%
pd.DataFrame.from_dict(df_dct).to_csv("../../data/final-crowdsourcing-experiments/ru/results/category-wise-SHR.csv", sep=',', index=False)

# %% [markdown]
# ## Count category-wise-scores

# %%
topics_dir = "/home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics"

for file in os.listdir(topics_dir):
    file_path = os.path.join(topics_dir, file.replace(" ", "\ "))
    output_path = os.path.join("/home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics-scores", file.replace(" ", "\ "))
    output = subprocess.check_output(f"/home/ins-alex/multilingual-qa-with-ranking/external-scripts/Best-Worst-Scaling-Scripts/get-scores-from-BWS-annotations-counting.pl {file_path} > {output_path}", shell=True, universal_newlines=True)
# Out:
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/англичане.csv ...
# Read 300 annotations.
# Found 13 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/штат США.csv ...
# Read 204 annotations.
# Found 17 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/специалист в области информатики.csv ...
# Read 180 annotations.
# Found 15 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/американцы США.csv ...
# Read 332 annotations.
# Found 14 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/турки.csv ...
# Read 312 annotations.
# Found 14 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/спортивный симулятор.csv ...
# Read 421 annotations.
# Found 18 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/рождественский фильм.csv ...
# Read 225 annotations.
# Found 19 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/животные.csv ...
# Read 180 annotations.
# Found 15 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/политолог.csv ...
# Read 236 annotations.
# Found 20 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/криминальный телесериал.csv ...
# Read 431 annotations.
# Found 18 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/научная фантастика на телевидении.csv ...
# WARNING: Annotations for the Best and Worst items are identical in line 236.
# Read 370 annotations.
# Found 16 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/литература ужасов.csv ...
# Read 192 annotations.
# Found 16 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/боевые искусства.csv ...
# Read 168 annotations.
# Found 14 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/музыкальная компьютерная игра.csv ...
# Read 271 annotations.
# Found 23 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/бас гитарист.csv ...
# Read 203 annotations.
# Found 17 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/музей современного искусства.csv ...
# Read 140 annotations.
# Found 12 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/президент США.csv ...
# Read 276 annotations.
# Found 13 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/актёр.csv ...
# Read 515 annotations.
# Found 22 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/приключенческий фильм.csv ...
# Read 179 annotations.
# Found 15 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/action.csv ...
# Read 193 annotations.
# Found 17 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/фильм тайна.csv ...
# Read 204 annotations.
# Found 17 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/рэпер.csv ...
# Read 467 annotations.
# Found 20 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/философ.csv ...
# Read 396 annotations.
# Found 17 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/спортсмен.csv ...
# Read 200 annotations.
# Found 17 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/многопользовательская игра.csv ...
# Read 261 annotations.
# Found 22 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/шпионский фильм.csv ...
# Read 204 annotations.
# Found 17 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/гора.csv ...
# Read 432 annotations.
# Found 18 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/инженер.csv ...
# Read 379 annotations.
# Found 17 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/математик.csv ...
# Read 207 annotations.
# Found 18 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/архитектор.csv ...
# Read 200 annotations.
# Found 17 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/китайцы.csv ...
# Read 189 annotations.
# Found 10 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/криминальный фильм.csv ...
# Read 209 annotations.
# Found 18 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/афроамериканцы.csv ...
# Read 360 annotations.
# Found 16 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/баскетболист.csv ...
# Read 226 annotations.
# Found 19 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/музыкальный жанр.csv ...
# Read 257 annotations.
# Found 22 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/скульптура.csv ...
# Read 254 annotations.
# Found 22 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/индийцы.csv ...
# Read 308 annotations.
# Found 14 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/фильм ужасов.csv ...
# Read 257 annotations.
# Found 22 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/100 женщин.csv ...
# Read 367 annotations.
# Found 16 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/немцы.csv ...
# Read 180 annotations.
# Found 10 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/фильм сказка.csv ...
# Read 408 annotations.
# Found 18 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/гитарист.csv ...
# Read 259 annotations.
# Found 22 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/итальянцы.csv ...
# Read 322 annotations.
# Found 14 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/боевик.csv ...
# Read 429 annotations.
# Found 18 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/спортивный фильм.csv ...
# Read 213 annotations.
# Found 18 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/теннисист.csv ...
# Read 192 annotations.
# Found 16 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/компьютерная стратегическая игра.csv ...
# Read 226 annotations.
# Found 19 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/борец за права женщин.csv ...
# Read 201 annotations.
# Found 17 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/учёный.csv ...
# Read 228 annotations.
# Found 19 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/джазмен.csv ...
# WARNING: Annotations for the Best and Worst items are identical in line 195.
# Read 345 annotations.
# Found 15 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/модельер.csv ...
# Read 189 annotations.
# Found 16 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/исторический фильм.csv ...
# Read 262 annotations.
# Found 22 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/растения.csv ...
# Read 238 annotations.
# Found 20 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/пианист.csv ...
# Read 203 annotations.
# Found 17 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/комедийный телесериал.csv ...
# Read 396 annotations.
# Found 17 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/пейзажист.csv ...
# Read 164 annotations.
# Found 14 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/романтический фильм.csv ...
# Read 264 annotations.
# Found 22 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/детский фильм.csv ...
# Read 359 annotations.
# Found 16 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/военный фильм.csv ...
# Read 224 annotations.
# Found 19 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/однопользовательская игра.csv ...
# Read 201 annotations.
# Found 17 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/художник.csv ...
# Read 406 annotations.
# Found 18 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/человек, связанный со спортом.csv ...
# Read 187 annotations.
# Found 16 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/телефильм.csv ...
# Read 564 annotations.
# Found 24 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/стендап комик.csv ...
# Read 228 annotations.
# Found 19 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/аниме фильм.csv ...
# Read 372 annotations.
# Found 16 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/биолог.csv ...
# Read 488 annotations.
# Found 21 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/драматический сериал.csv ...
# Read 188 annotations.
# Found 16 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/программист.csv ...
# Read 178 annotations.
# Found 15 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/экономист.csv ...
# Read 408 annotations.
# Found 18 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/большой город в США.csv ...
# Read 355 annotations.
# Found 16 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/барабанщик.csv ...
# Read 204 annotations.
# Found 17 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/русские.csv ...
# Read 299 annotations.
# Found 14 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/3D фильм.csv ...
# Read 423 annotations.
# Found 18 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/мультфильм.csv ...
# Read 464 annotations.
# Found 20 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics/интернет мем.csv ...
# Read 192 annotations.
# Found 17 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.

# %% [markdown]
# # Merge scores with wikidata ids and topics

# %%
def find_topic_uri(label, file):
    with open(file + ".json") as f:
        data = json.load(f)

    try:
        uri = next(key for key, val in data.items() if val == label)
    except:
        return ""
    
    try:
        return "http://www.wikidata.org/entity/" + uri
    except:
        print(label)
        return ""

# %%
scores_path = "/home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru/topics-scores"
main_path = "/home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/ru"
for file in os.listdir(scores_path):
    print(file)
    df = pd.read_csv(os.path.join(scores_path, file), sep='\t', header=None)
    df["URI"] = df[0].apply(lambda x: find_topic_uri(x, os.path.join(main_path, file.replace(".csv", "").replace(" ", "-"))))
    df["topic"] = file.replace(".csv", "")
    df.to_csv(os.path.join(scores_path, file), sep='\t', index=False, header=None)
# Out:
# англичане.csv
# штат США.csv
# специалист в области информатики.csv
# американцы США.csv
# турки.csv
# спортивный симулятор.csv
# рождественский фильм.csv
# животные.csv
# политолог.csv
# криминальный телесериал.csv
# научная фантастика на телевидении.csv
# литература ужасов.csv
# боевые искусства.csv
# музыкальная компьютерная игра.csv
# бас гитарист.csv
# музей современного искусства.csv
# президент США.csv
# актёр.csv
# приключенческий фильм.csv
# action.csv
# фильм тайна.csv
# рэпер.csv
# философ.csv
# спортсмен.csv
# многопользовательская игра.csv
# шпионский фильм.csv
# гора.csv
# инженер.csv
# математик.csv
# архитектор.csv
# китайцы.csv
# криминальный фильм.csv
# афроамериканцы.csv
# баскетболист.csv
# музыкальный жанр.csv
# скульптура.csv
# индийцы.csv
# фильм ужасов.csv
# 100 женщин.csv
# немцы.csv
# фильм сказка.csv
# гитарист.csv
# итальянцы.csv
# боевик.csv
# спортивный фильм.csv
# теннисист.csv
# компьютерная стратегическая игра.csv
# борец за права женщин.csv
# учёный.csv
# джазмен.csv
# модельер.csv
# исторический фильм.csv
# растения.csv
# пианист.csv
# комедийный телесериал.csv
# пейзажист.csv
# романтический фильм.csv
# детский фильм.csv
# военный фильм.csv
# однопользовательская игра.csv
# художник.csv
# человек, связанный со спортом.csv
# телефильм.csv
# стендап комик.csv
# аниме фильм.csv
# биолог.csv
# драматический сериал.csv
# программист.csv
# экономист.csv
# большой город в США.csv
# барабанщик.csv
# русские.csv
# 3D фильм.csv
# мультфильм.csv
# интернет мем.csv

# %%
# Directory containing the .csv files
directory = '../../data/final-crowdsourcing-experiments/ru/topics-scores'

# Output file path
output_file = '../../data/final-crowdsourcing-experiments/ru/results/final-scores.csv'

# Initialize an empty DataFrame to store the merged data
merged_data = pd.DataFrame()

# Loop through each file in the directory
for file in os.listdir(directory):
    if file.endswith('.csv'):
        # Read the current file
        file_path = os.path.join(directory, file)
        data = pd.read_csv(file_path, sep='\t', header=None)
        
        # Append the data to the merged DataFrame
        merged_data = merged_data.append(data, ignore_index=True)

# Write the merged data to the output file
merged_data.to_csv(output_file, index=False)
# Out:
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_20163/1163519999.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
