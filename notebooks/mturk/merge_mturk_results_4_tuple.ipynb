# %%
import os
import json
import pandas as pd
from SPARQLWrapper import SPARQLWrapper, JSON

# %%
filename = "Batch_5144830_batch_results"
columns = [ 'Input.1label',
 'Input.1real',
 'Input.1a',
 'Input.1b',
 'Input.1c',
 'Input.1d',
 'Input.2label',
 'Input.2real',
 'Input.2a',
 'Input.2b',
 'Input.2c',
 'Input.2d',
 'Input.3label',
 'Input.3real',
 'Input.3a',
 'Input.3b',
 'Input.3c',
 'Input.3d',
 'Input.4label',
 'Input.4real',
 'Input.4a',
 'Input.4b',
 'Input.4c',
 'Input.4d',
 'Input.5label',
 'Input.5real',
 'Input.5a',
 'Input.5b',
 'Input.5c',
 'Input.5d',
 'Answer.Least1.a',
 'Answer.Least1.b',
 'Answer.Least1.c',
 'Answer.Least1.d',
 'Answer.Least2.a',
 'Answer.Least2.b',
 'Answer.Least2.c',
 'Answer.Least2.d',
 'Answer.Least3.a',
 'Answer.Least3.b',
 'Answer.Least3.c',
 'Answer.Least3.d',
 'Answer.Least4.a',
 'Answer.Least4.b',
 'Answer.Least4.c',
 'Answer.Least4.d',
 'Answer.Least5.a',
 'Answer.Least5.b',
 'Answer.Least5.c',
 'Answer.Least5.d',
 'Answer.Most1.a',
 'Answer.Most1.b',
 'Answer.Most1.c',
 'Answer.Most1.d',
 'Answer.Most2.a',
 'Answer.Most2.b',
 'Answer.Most2.c',
 'Answer.Most2.d',
 'Answer.Most3.a',
 'Answer.Most3.b',
 'Answer.Most3.c',
 'Answer.Most3.d',
 'Answer.Most4.a',
 'Answer.Most4.b',
 'Answer.Most4.c',
 'Answer.Most4.d',
 'Answer.Most5.a',
 'Answer.Most5.b',
 'Answer.Most5.c',
 'Answer.Most5.d',
 'Answer.Real1',
 'Answer.Real2',
 'Answer.Real3',
 'Answer.Real4',
 'Answer.Real5',]

# %%
df_raw = pd.read_csv(f"../../../Downloads/{filename}.csv")
df_raw = df_raw[columns]

# %% [markdown]
# # Convert to a standartized format
#
# e.g.:`["INPUT:topic", "INPUT:answer_1", "INPUT:answer_2", "INPUT:answer_3", "INPUT:answer_4", "OUTPUT:most", "OUTPUT:least", "GOLDEN:least", "GOLDEN:most"]`

# %%
# columns ["INPUT:topic", "INPUT:answer_1", "INPUT:answer_2", "INPUT:answer_3", "INPUT:answer_4", "OUTPUT:most", "OUTPUT:least"]
# 'Input.1label', 'Input.1real', 'Input.1a', 'Input.1b', 'Input.1c', 'Input.1d',

df_dict = {
    "INPUT:topic": [],
    "INPUT:answer_1": [],
    "INPUT:answer_2": [],
    "INPUT:answer_3": [],
    "INPUT:answer_4": [],
    "OUTPUT:most": [],
    "OUTPUT:least": [],
    # "GOLDEN:least": [], # skip for now, need in future
    # "GOLDEN:most": [] # not used
}

for i, row in df_raw.iterrows():
    for j in range(1, 6):
        df_dict["INPUT:topic"].append(row[f"Input.{j}label"])
        df_dict["INPUT:answer_1"].append(row[f"Input.{j}a"])
        df_dict["INPUT:answer_2"].append(row[f"Input.{j}b"])
        df_dict["INPUT:answer_3"].append(row[f"Input.{j}c"])
        df_dict["INPUT:answer_4"].append(row[f"Input.{j}d"])

        output_most = [row[f"Answer.Most{j}.a"], row[f"Answer.Most{j}.b"], row[f"Answer.Most{j}.c"], row[f"Answer.Most{j}.d"] ].index(True) + 1
        output_least = [row[f"Answer.Least{j}.a"], row[f"Answer.Least{j}.b"], row[f"Answer.Least{j}.c"], row[f"Answer.Least{j}.d"] ].index(True) + 1

        df_dict["OUTPUT:most"].append(output_most)
        df_dict["OUTPUT:least"].append(output_least)

        # TODO: add golden least and most

# %%
df_norm = pd.DataFrame.from_dict(df_dict)

# %%
df_norm
# Out:
#                    INPUT:topic                INPUT:answer_1  \
# 0               Christmas film                 Love Actually
# 1                  music genre                      nu metal
# 2           computer scientist                   Sergey Brin
# 3                tennis player              Alexander Zverev
# 4            martial arts film                 Keys to Power
# ...                        ...                           ...
# 16015        sports video game                          Pyre
# 16016              philosopher                    philosophy
# 16017   multiplayer video game                Dark Souls III
# 16018  crime television series                    Kuznetsova
# 16019        sports video game  Tony Hawk's Pro Skater 1 + 2
#
#                             INPUT:answer_2            INPUT:answer_3  \
# 0           Home Alone 2: Lost in New York     Kennedy Center Honors
# 1                                post-punk       Neue Deutsche Härte
# ...

# %% [markdown]
# # Count the correctenss of the control tasks

# %%
# TODO

# %% [markdown]
# # Prepare data for the external SHR script
#
# ## Full

# %%
# leave only important columns
df_shr = df_norm[["INPUT:topic", "INPUT:answer_1", "INPUT:answer_2", "INPUT:answer_3", "INPUT:answer_4", "OUTPUT:most", "OUTPUT:least"]]

# %%
df_shr_dict = {
    "Item1": list(),
    "Item2": list(),
    "Item3": list(),
    "Item4": list(),
    "BestItem": list(),
    "WorstItem": list()
}

for i, row in df_shr.iterrows():
    df_shr_dict["Item1"].append(row["INPUT:answer_1"])
    df_shr_dict["Item2"].append(row["INPUT:answer_2"])
    df_shr_dict["Item3"].append(row["INPUT:answer_3"])
    df_shr_dict["Item4"].append(row["INPUT:answer_4"])
    
    best_idx = row["OUTPUT:most"]
    worst_idx = row["OUTPUT:least"]
    
    df_shr_dict["BestItem"].append(row[f"INPUT:answer_{best_idx}"])
    df_shr_dict["WorstItem"].append(row[f"INPUT:answer_{worst_idx}"])

df_shr_full = pd.DataFrame(df_shr_dict)
df_shr_full.to_csv(f"../../../Downloads/{filename}_shr_full.csv", sep=",", index=False)

# %% [markdown]
# ## Category-wise

# %%
for topic in df_shr["INPUT:topic"].unique():
    df_shr_topic = df_shr[df_shr["INPUT:topic"] == topic]

    df_shr_dict = {
        "Item1": list(),
        "Item2": list(),
        "Item3": list(),
        "Item4": list(),
        "BestItem": list(),
        "WorstItem": list()
    }

    for i, row in df_shr_topic.iterrows():
        df_shr_dict["Item1"].append(row["INPUT:answer_1"])
        df_shr_dict["Item2"].append(row["INPUT:answer_2"])
        df_shr_dict["Item3"].append(row["INPUT:answer_3"])
        df_shr_dict["Item4"].append(row["INPUT:answer_4"])
        
        best_idx = row["OUTPUT:most"]
        worst_idx = row["OUTPUT:least"]
        
        df_shr_dict["BestItem"].append(row[f"INPUT:answer_{best_idx}"])
        df_shr_dict["WorstItem"].append(row[f"INPUT:answer_{worst_idx}"])

    df_shr_topic = pd.DataFrame(df_shr_dict)
    df_shr_topic.to_csv(f"../../data/final-crowdsourcing-experiments/en/topics/{topic}.csv", sep=",", index=False)

# %% [markdown]
# # Create files with scores
#
# ## Count SHR for topics

# %%
import re
import subprocess

topics_dir = "/home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/en/topics"
df_dct = {"topic": [], "Spearman": [], "Pearson": []}
for file in os.listdir(topics_dir):
    if ".scores" in file:
        continue
    file_path = os.path.join(topics_dir, file.replace(" ", "\ ").replace("'","\\'"))
    output = subprocess.check_output(f"/home/ins-alex/multilingual-qa-with-ranking/external-scripts/Best-Worst-Scaling-Scripts/SHR-BWS.pl {file_path}", shell=True, universal_newlines=True)
    lst = output.split("\n")
    pattern_1 = r"Spearman correlation: ([\d.]+)"
    pattern_2 = r"Pearson correlation: ([\d.]+)"    

    match_1 = re.search(pattern_1, lst[0]).group(1)
    match_2 = re.search(pattern_2, lst[1]).group(1)

    df_dct["topic"].append(file.replace(".csv", ""))
    df_dct["Spearman"].append(match_1)
    df_dct["Pearson"].append(match_2)
# Out:
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/en/topics/biologist.csv ...
# Read 280 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/en/topics/war film.csv ...
# Read 234 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/en/topics/political scientist.csv ...
# Read 223 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/en/topics/martial arts film.csv ...
# Read 167 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/en/topics/architect.csv ...
# Read 200 annotations.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/en/topics/drummer.csv ...
# Read 206 annotations.
# ...

# %%
pd.DataFrame.from_dict(df_dct).to_csv("../../data/final-crowdsourcing-experiments/en/results/category-wise-SHR.csv", sep=',', index=False)

# %% [markdown]
# # Count category-wise scores

# %%
topics_dir = "/home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/en/topics"

for file in os.listdir(topics_dir):
    if ".scores" in file:
        continue
    file_path = os.path.join(topics_dir, file.replace(" ", "\ ").replace("'","\\'"))
    output_path = os.path.join("/home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/en/topics-scores", file.replace(" ", "\ ").replace("'","\\'"))
    output = subprocess.check_output(f"/home/ins-alex/multilingual-qa-with-ranking/external-scripts/Best-Worst-Scaling-Scripts/get-scores-from-BWS-annotations-counting.pl {file_path} > {output_path}", shell=True, universal_newlines=True)
# Out:
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/en/topics/biologist.csv ...
# Read 280 annotations.
# Found 69 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/en/topics/war film.csv ...
# Read 234 annotations.
# Found 49 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# Reading the annotation file /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/en/topics/political scientist.csv ...
# Read 223 annotations.
# Found 35 unique items.
#
# Writing the scores to STDOUT ...
# Finished.
#
# Writing the scores to OUTF ...
# Finished.
# ...

# %% [markdown]
# # Merge scores with wikidata ids and topics

# %%
# df_shr_full_scores = pd.read_csv(f"../../data/final-crowdsourcing-experiments/en/results/final-scores.csv", sep="\t", header=None)

# %%
def find_topic_uri(label, file):
    with open(file + ".json") as f:
        data = json.load(f)

    try:
        uri = next(key for key, val in data.items() if val == label)
    except:
        print(file, "-->", label)
        return ""
    
    try:
        return "http://www.wikidata.org/entity/" + uri
    except:
        print(file, "-->", label)
        return ""

# %%
scores_path = "/home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/en/topics-scores"
main_path = "/home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/en"
for file in os.listdir(scores_path):
    # print(file)
    df = pd.read_csv(os.path.join(scores_path, file), sep='\t', header=None)
    df["URI"] = df[0].apply(lambda x: find_topic_uri(x, os.path.join(main_path, file.replace(".csv", "").replace(" ", "-"))))
    df["topic"] = file.replace(".csv", "")
    df = df[df.URI != ""]
    df.to_csv(os.path.join(scores_path, file), sep='\t', index=False, header=None)
# Out:
# /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/en/biologist --> Dmitry Formulary
# /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/en/biologist --> Nefertiti Bust
# /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/en/biologist --> Elena Landscapeva
# /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/en/biologist --> Mesut Özil
# /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/en/biologist --> Los York
# /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/en/biologist --> Alexey Scholarov
# /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/en/biologist --> Michael Groove
# /home/ins-alex/multilingual-qa-with-ranking/data/final-crowdsourcing-experiments/en/biologist --> Elena Philosopherova
# ...

# %%
# Directory containing the .csv files
directory = '../../data/final-crowdsourcing-experiments/en/topics-scores'

# Output file path
output_file = '../../data/final-crowdsourcing-experiments/en/results/final-scores.csv'

# Initialize an empty DataFrame to store the merged data
merged_data = pd.DataFrame()

# Loop through each file in the directory
for file in os.listdir(directory):
    if file.endswith('.csv'):
        # Read the current file
        file_path = os.path.join(directory, file)
        data = pd.read_csv(file_path, sep='\t', header=None)
        
        # Append the data to the merged DataFrame
        merged_data = merged_data.append(data, ignore_index=True)

# Write the merged data to the output file
merged_data.to_csv(output_file, index=False)
# Out:
# /tmp/ipykernel_8858/532218004.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_8858/532218004.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_8858/532218004.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# /tmp/ipykernel_8858/532218004.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data, ignore_index=True)
# ...
